# %%
import pandas as pd

# %%
attendance_df = pd.read_csv('data.csv', usecols=[0, 1, 2, 3, 4], header=None)
attendance_df = attendance_df.rename(columns={0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4: 'Friday'})
attendance_df.head()
# Out:
#     Monday  Tuesday Wednesday Thursday   Friday
# 0  8:56 AM  9:00 AM   7:45 AM  7:45 AM  8:05 AM
# 1  8:40 AM  8:40 AM   8:30 AM  8:30 AM  8:45 AM
# 2  8:45 AM  8:20 AM   8:05 AM  8:00 AM  8:05 AM
# 3  8:40 AM  8:40 AM   8:40 AM  8:25 AM  8:40 AM
# 4  8:55 AM  8:50 AM   8:55 AM  8:10 AM  8:15 AM

# %%
attendance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
# Monday       23 non-null object
# Tuesday      23 non-null object
# Wednesday    23 non-null object
# Thursday     23 non-null object
# Friday       23 non-null object
# dtypes: object(5)
# memory usage: 1000.0+ bytes

# %%
attendance_df
# Out:
#      Monday   Tuesday Wednesday Thursday   Friday
# 0   8:56 AM   9:00 AM   7:45 AM  7:45 AM  8:05 AM
# 1   8:40 AM   8:40 AM   8:30 AM  8:30 AM  8:45 AM
# 2   8:45 AM   8:20 AM   8:05 AM  8:00 AM  8:05 AM
# 3   8:40 AM   8:40 AM   8:40 AM  8:25 AM  8:40 AM
# 4   8:55 AM   8:50 AM   8:55 AM  8:10 AM  8:15 AM
# 5   8:45 AM   8:45 AM   8:45 AM  8:40 AM  8:30 AM
# 6   8:45 AM   8:54 AM   8:38 AM  8:40 AM  8:32 AM
# 7    absent  11:00 AM   8:35 AM  8:15 AM  8:10 AM
# 8   8:39 AM   8:13 AM   8:15 AM  8:12 AM  8:10 AM
# 9   9:00 AM   8:50 AM   8:50 AM  8:50 AM  8:40 AM
# 10  8:40 AM   8:50 AM   8:40 AM  8:34 AM  8:20 AM
# 11  8:15 AM   8:30 AM   8:13 AM  8:30 AM  7:45 AM
# 12  8:45 AM   8:55 AM   8:45 AM  8:45 AM  8:00 AM
# 13  8:45 AM   8:45 AM   8:05 AM  8:00 AM  8:00 AM
# 14  8:45 AM   8:45 AM   9:00 AM  9:00 AM  8:50 AM
# 15  8:15 AM   8:40 AM   8:25 AM  8:30 AM  7:30 AM
# 16  8:45 AM   8:40 AM   8:45 AM  8:55 AM  8:45 AM
# 17  8:45 AM   9:00 AM   9:00 AM  9:00 AM  9:00 AM
# ...

# %% [markdown]
# There is no missing data, however there is an absence on Monday.

# %%
attendance_df = attendance_df.pd.Timestamp()
attendance_df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-388568f9abc8> in <module>()
# ----> 1 attendance_df = attendance_df.pd.Timestamp()
#       2 attendance_df.info()
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pd'
